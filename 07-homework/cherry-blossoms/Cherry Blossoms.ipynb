# %% [markdown]
# # Cherry Blossoms!
#
# If we travel back in time a few months, [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were in full bloom! We don't live in Japan or DC, but we do have our fair share of the trees - buuut you sadly missed [Brooklyn Botanic Garden's annual festival](https://www.bbg.org/visit/event/sakura_matsuri_2019).
#
# We'll have to make up for it with data-driven cherry blossoms instead. Once upon a time [Data is Plural](https://tinyletter.com/data-is-plural) linked to [a dataset](http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/) about when the cherry trees blossom each year. It's a little out of date, but it's quirky in a real nice way so we're sticking with it.
#
# ## 0. Do all of your importing/setup stuff

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## 1. Read in the file using pandas, and look at the first five rows

# %%
df = pd.read_excel("KyotoFullFlower7.xls", encoding='latin-1')
df.head()
# Out:
#   Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 0  This phenological data was acquired by followi...
# 1                                                NaN
# 2                                     Column A; A.D.
# 3       Column B; Full-flowering date (day of year).
# 4  Column C; Full-flowering date (calender date, ...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# ## 2. Read in the file using pandas CORRECTLY, and look at the first five rows
#
# Hrm, how do your column names look? Read the file in again but this time add a parameter to make sure your columns look right.
#
# **TIP: The first year should be 801 AD, and it should not have any dates or anything.**

# %%
df = pd.read_excel("KyotoFullFlower7.xls", encoding='latin-1', skiprows=25, na_values=['-', 'NaN'])
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %% [markdown]
# ## 3. Look at the final five rows of the data

# %%
df.tail(5)
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## 4. Add some more NaN values

# %% [markdown]
# It looks like you should probably have some NaN/missing values earlier on in the dataset under "Reference name." Read in the file *one more time*, this time making sure all of those missing reference names actually show up as `NaN` instead of `-`.

# %%
# did it above

# %%
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %% [markdown]
# ## 4. What source is the most common as a reference?

# %%
df['Reference Name'].value_counts()
# Out:
# NEWS-PAPER(ARASHIYAMA)                     94
# SUGIURAKE-NIKKI                            38
# MYOHOIN-HINAMIKI                           32
# OYUDONONO-UENO-NIKKI                       26
# DAIGOJI-ZATSUYO                            21
# OYUDONONO-UENO-NIKKI [EDA]                 21
# NIHONKIRYAKU                               19
# SANETAKA-KOKI                              19
# (SHIRYO-SORAN)                             15
# KAKUMEIKI                                  15
# ZOKU-SHIGUSHO                              14
# NISUIKI                                    13
# INRYOGEN-NICHIROKU                         13
# MEIGETSUKI                                 12
# GIENJUNKO-NIKKI(DAIGO)                     10
# GUKANKI                                    10
# KANMON-GYOKI(FUSHIMI)                       9
# DAIGO-ZOJIKI                                9
# MOTOHIRO-KOKI                               9
# KEIHAN RAILWAY ADV(ARASHIYAMA)              9
# TERUYOSHI-KOKI                              8
# TOKITSUGU-KYOKI                             8
# RAI-SANYO-NIPPU                             8
# MANZAIJUNGO-NIKKI(DAIGO)                    8
# TOKIYOSHI-KYOKI                             8
# ZOKU-HONCHOTSUKAN                           8
# HANAZONOTENNO-SHINKI                        8
# TAKAGI-ZAICHU-NIKKI                         8
# (DAINIHON-SHIRYO)                           7
# GONIJO-MOROMICHIKI                          6
#                                            ..
# GAUN-NIKKENROKU-BATSUYU                     1
# GONARAIN-SHINNKI                            1
# KUJO-TADAMOTO-NIKKI                         1
# SHIN-SENZAI-WAKASHU                         1
# GEIYOKI                                     1
# ZOKU-SHIGUSHO(DAIGO)                        1
# EST-from-WF(KIMITADA-SHU)                   1
# SHIKIN-WAKASO                               1
# MITAMURA-ENGYO-NIKKI(ARASHIYAMA)            1
# EST-from-KJ(NORIMUNE-SHU)                   1
# REKIDAI-HENNEN-SHUSEI                       1
# MYOHOIN-HINAMIKI [ARASHIYAMA]               1
# SEKI-HAJIME-NIKKI                           1
# KINHISHO                                    1
# TOKITSUNE-KYOKI(DAIGO)                      1
# SAMPOIN-MONJO                               1
# HEKIZAN-NICHIROKU                           1
# KOBE-TETSUDO-KANRIKYOKU ADV(ARASHIYAMA)     1
# EISHOKI                                     1
# EIGA-MONOGATARI(MATSUNO-SHIDUE)             1
# NORITOKI-KYOKI                              1
# SHOHO-2-NEN-IKO-NIKKI                       1
# KOUKANSIYU-NIKKI                            1
# ROKUON-NICHIROKU                            1
# YANAGIHARA-KOREMITSU-NIKKI                  1
# KANEKA-KYOKI                                1
# EST-from-WF(NIHONGI-RYAKU)                  1
# MORIMITSU-KOKI                              1
# NAKAYAMAISAKO-NIKKI                         1
# FUDEMAKASE                                  1
# Name: Reference Name, Length: 222, dtype: int64

# %% [markdown]
# ## 6. Filter the list to only include columns where the `Full-flowering date (DOY)` is not missing
#
# If you'd like to do it in two steps (which might be easier to think through), first figure out how to test whether a column is empty/missing/null/NaN, get the list of `True`/`False` values, and then later feed it to your `df`.

# %%
df = df.dropna(subset=['Full-flowering date (DOY)'])
df.head(10)
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11  812                       92.0                401.0          1.0
# 14  815                      105.0                415.0          1.0
# 30  831                       96.0                406.0          1.0
# 50  851                      108.0                418.0          1.0
# 52  853                      104.0                414.0          1.0
# 63  864                      100.0                409.0          1.0
# 65  866                      106.0                416.0          1.0
# 68  869                       95.0                405.0          5.0
# 88  889                      104.0                414.0          5.0
# 90  891                      109.0                419.0          5.0
#
#     Data type code           Reference Name
# 11             2.0               NIHON-KOKI
# 14             2.0               NIHON-KOKI
# 30             2.0               NIHON-KOKI
# 50             2.0   MONTOKUTENNO-JITSUROKU
# 52             2.0   MONTOKUTENNO-JITSUROKU
# 63             2.0  NIPPON-SANDAI-JITSUROKU
# 65             2.0  NIPPON-SANDAI-JITSUROKU
# 68             2.0             KANKE-BUNSOU
# 88             2.0  NIPPON-SANDAI-JITSUROKU
# 90             4.0             NIHONKIRYAKU

# %% [markdown]
# ## 7. Make a histogram of the full-flowering date
#
# Is it not showing up? Remember the "magic" command that makes graphs show up in matplotlib notebooks!

# %%
df['Full-flowering date (DOY)'].hist()

# %% [markdown]
# ## 8. Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df['Full-flowering date (DOY)'].hist(bins=39)

# %% [markdown]
# ## 9. What's the average number of days it takes for the flowers to blossom? And how many records do we have?
#
# Answer these both with one line of code.

# %%
df['Full-flowering date (DOY)'].describe()
# Out:
# count    827.000000
# mean     104.540508
# std        6.407036
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: Full-flowering date (DOY), dtype: float64

# %% [markdown]
# ## 10. What's the average days into the year cherry flowers normally blossomed before 1900?

# %%
df[df.AD < 1900]['Full-flowering date (DOY)'].mean()
# Out:
# 105.20728291316527

# %% [markdown]
# ## 11. How about after 1900?

# %%
df[df.AD > 1900]['Full-flowering date (DOY)'].mean()
# Out:
# 100.3125

# %% [markdown]
# ## 12. How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
df[df['Data type code'] == 4.0].shape
# Out:
# (39, 6)

# %% [markdown]
# ## 13. Show only the years where our data was from a title in Japanese poetry

# %%
df[df['Data type code'] == 4.0].AD
# Out:
# 90       891
# 94       895
# 95       896
# 122      923
# 154      955
# 168      969
# 206     1007
# 232     1033
# 235     1036
# 259     1060
# 260     1061
# 283     1084
# 294     1095
# 381     1182
# 389     1190
# 400     1201
# 415     1216
# 418     1219
# 420     1221
# 422     1223
# 435     1236
# 464     1265
# 467     1268
# 468     1269
# 470     1271
# 488     1289
# 500     1301
# 523     1324
# 529     1330
# 646     1447
# 652     1453
# 653     1454
# 673     1474
# 733     1534
# 791     1592
# 839     1640
# 860     1661
# 1045    1846
# 1062    1863
# Name: AD, dtype: int64

# %% [markdown]
# ## 14. Graph the full-flowering date (DOY) over time

# %%
df.plot(x='AD', y='Full-flowering date (DOY)', kind='line', color='pink', figsize=(10, 3))

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
df.rolling(10, on='AD', min_periods=5)['Full-flowering date (DOY)'].mean().tail()
# Out:
# 1210    95.9
# 1211    96.9
# 1212    96.4
# 1213    96.6
# 1214    96.0
# Name: Full-flowering date (DOY), dtype: float64

# %%
rolling_date = df.rolling(20, on='AD', min_periods=5)['Full-flowering date (DOY)'].mean()
df['rolling_date'] = rolling_date = df.rolling(20, on='AD', min_periods=5)['Full-flowering date (DOY)'].mean()
df.head(10)
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11  812                       92.0                401.0          1.0
# 14  815                      105.0                415.0          1.0
# 30  831                       96.0                406.0          1.0
# 50  851                      108.0                418.0          1.0
# 52  853                      104.0                414.0          1.0
# 63  864                      100.0                409.0          1.0
# 65  866                      106.0                416.0          1.0
# 68  869                       95.0                405.0          5.0
# 88  889                      104.0                414.0          5.0
# 90  891                      109.0                419.0          5.0
#
#     Data type code           Reference Name  rolling_date
# 11             2.0               NIHON-KOKI           NaN
# 14             2.0               NIHON-KOKI           NaN
# 30             2.0               NIHON-KOKI           NaN
# 50             2.0   MONTOKUTENNO-JITSUROKU           NaN
# 52             2.0   MONTOKUTENNO-JITSUROKU    101.000000
# 63             2.0  NIPPON-SANDAI-JITSUROKU    100.833333
# 65             2.0  NIPPON-SANDAI-JITSUROKU    101.571429
# 68             2.0             KANKE-BUNSOU    100.750000
# 88             2.0  NIPPON-SANDAI-JITSUROKU    101.111111
# 90             4.0             NIHONKIRYAKU    101.900000

# %% [markdown]
# Use the code above to create a new column called `rolling_date` in our dataset. It should be the 20-year rolling average of the flowering date. Then plot it, with the year on the x axis and the day of the year on the y axis.
#
# Try adding `ylim=(80, 120)` to your `.plot` command to make things look a little less dire.

# %%
df.plot(x='AD', y='rolling_date', kind='line', ylim=(80, 120))

# %% [markdown]
# ### 16. Add a month column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.
#
# **I've given you March as an example**, you just need to add in two more lines to do April and May.

# %%
df.loc[df['Full-flowering date'] < 400, 'month'] = 'March'

# %%
df.loc[(df['Full-flowering date'] > 400) & (df['Full-flowering date'] < 500), 'month'] = 'April'

# %%
df.loc[df['Full-flowering date'] > 500, 'month'] = 'May'

df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11     812                       92.0                401.0          1.0
# 14     815                      105.0                415.0          1.0
# 30     831                       96.0                406.0          1.0
# 50     851                      108.0                418.0          1.0
# 52     853                      104.0                414.0          1.0
# 63     864                      100.0                409.0          1.0
# 65     866                      106.0                416.0          1.0
# 68     869                       95.0                405.0          5.0
# 88     889                      104.0                414.0          5.0
# 90     891                      109.0                419.0          5.0
# 91     892                      108.0                417.0          5.0
# 93     894                      106.0                416.0          5.0
# 94     895                      104.0                414.0          5.0
# 95     896                      104.0                413.0          5.0
# 101    902                      102.0                412.0          5.0
# 107    908                       98.0                407.0          5.0
# 111    912                       95.0                404.0          1.0
# 112    913                      110.0                420.0          5.0
# 116    917                       95.0                405.0          1.0
# 122    923                      104.0                414.0          5.0
# 125    926                       98.0                408.0          1.0
# 129    930                       97.0                407.0          5.0
# 132    933                      106.0                416.0          5.0
# 140    941                      109.0                419.0          1.0
# 148    949                      107.0                417.0          1.0
# 149    950                       95.0                405.0          4.0
# 154    955                       89.0                330.0          5.0
# 156    957                      112.0                422.0          1.0
# 157    958                      109.0                419.0          1.0
# 158    959                       97.0                407.0          3.0
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code              Reference Name  rolling_date  month
# 11               2.0                  NIHON-KOKI           NaN  April
# 14               2.0                  NIHON-KOKI           NaN  April
# 30               2.0                  NIHON-KOKI           NaN  April
# 50               2.0      MONTOKUTENNO-JITSUROKU           NaN  April
# 52               2.0      MONTOKUTENNO-JITSUROKU    101.000000  April
# 63               2.0     NIPPON-SANDAI-JITSUROKU    100.833333  April
# 65               2.0     NIPPON-SANDAI-JITSUROKU    101.571429  April
# 68               2.0                KANKE-BUNSOU    100.750000  April
# 88               2.0     NIPPON-SANDAI-JITSUROKU    101.111111  April
# 90               4.0                NIHONKIRYAKU    101.900000  April
# 91               3.0         FUSHIMIIN-GOKIROKKU    102.454545  April
# 93               2.0                KANKE-BUNSOU    102.750000  April
# 94               4.0                NIHONKIRYAKU    102.846154  April
# 95               4.0     NIPPON-SANDAI-JITSUROKU    102.928571  April
# 101              8.0  EST-from-WF(NIHONGI-RYAKU)    102.866667  April
# 107              8.0   EST-from-WF(KIMITADA-SHU)    102.562500  April
# 111              2.0                 SHINGISHIKI    102.117647  April
# 112              2.0                SHUI-WAKASHU    102.555556  April
# 116              2.0                    KINHISHO    102.157895  April
# 122              4.0          ZOKU-KOKIN-WAKASHU    102.250000  April
# 125              2.0                NIHONKIRYAKU    102.550000  April
# 129              8.0   EST-from-WF(SHIRYO-SORAN)    102.150000  April
# 132              8.0   EST-from-WF(SHIRYO-SORAN)    102.650000  April
# 140              2.0                NIHONKIRYAKU    102.700000  April
# 148              2.0                NIHONKIRYAKU    102.850000  April
# 149              2.0             DAINIHON-SHIRYO    102.600000  April
# 154              4.0                     SHUISHO    101.750000  March
# 156              2.0                NIHONKIRYAKU    102.600000  April
# 157              2.0                NIHONKIRYAKU    102.850000  April
# 158              2.0                     KYUREKI    102.250000  April
# ...              ...                         ...           ...    ...
# 1185             0.0      NEWS-PAPER(ARASHIYAMA)     99.650000  April
# 1186             0.0      NEWS-PAPER(ARASHIYAMA)     99.550000  April
# 1187             0.0      NEWS-PAPER(ARASHIYAMA)     99.900000  April
# 1188             0.0      NEWS-PAPER(ARASHIYAMA)     99.500000  April
# 1189             0.0      NEWS-PAPER(ARASHIYAMA)     98.550000  March
# 1190             0.0      NEWS-PAPER(ARASHIYAMA)     98.500000  April
# 1191             0.0      NEWS-PAPER(ARASHIYAMA)     98.250000  April
# 1192             0.0      NEWS-PAPER(ARASHIYAMA)     98.250000  April
# 1193             0.0      NEWS-PAPER(ARASHIYAMA)     98.250000  April
# 1194             0.0      NEWS-PAPER(ARASHIYAMA)     98.200000  April
# 1195             0.0      NEWS-PAPER(ARASHIYAMA)     98.400000  April
# 1196             0.0      NEWS-PAPER(ARASHIYAMA)     98.600000  April
# 1197             0.0      NEWS-PAPER(ARASHIYAMA)     97.950000  April
# 1198             0.0      NEWS-PAPER(ARASHIYAMA)     97.800000  April
# 1199             0.0      NEWS-PAPER(ARASHIYAMA)     97.700000  April
# 1200             0.0      NEWS-PAPER(ARASHIYAMA)     97.550000  April
# 1201             0.0      NEWS-PAPER(ARASHIYAMA)     97.450000  April
# 1202             0.0      NEWS-PAPER(ARASHIYAMA)     97.400000  April
# 1203             0.0      NEWS-PAPER(ARASHIYAMA)     96.550000  April
# 1204             0.0      NEWS-PAPER(ARASHIYAMA)     96.550000  April
# 1205             0.0      NEWS-PAPER(ARASHIYAMA)     96.350000  April
# 1206             0.0      NEWS-PAPER(ARASHIYAMA)     96.450000  April
# 1207             0.0      NEWS-PAPER(ARASHIYAMA)     95.900000  April
# 1208             0.0      NEWS-PAPER(ARASHIYAMA)     96.000000  April
# 1209             0.0      NEWS-PAPER(ARASHIYAMA)     96.350000  April
# 1210             0.0      NEWS-PAPER(ARASHIYAMA)     96.450000  April
# 1211             0.0      NEWS-PAPER(ARASHIYAMA)     96.800000  April
# 1212             0.0      NEWS-PAPER(ARASHIYAMA)     96.600000  April
# 1213             0.0      NEWS-PAPER(ARASHIYAMA)     96.350000  April
# 1214             0.0      NEWS-PAPER(ARASHIYAMA)     96.050000  April
#
# [827 rows x 8 columns]

# %% [markdown]
# ### 17. Using your new column, how many blossomings happened in each month?

# %%
df.month.value_counts()
# Out:
# April    814
# March     10
# May        3
# Name: month, dtype: int64

# %% [markdown]
# ### 18. Graph how many blossomings happened in each month.

# %%
df.month.value_counts().plot(kind='bar')

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called "day of month." It's actually a little tougher than it should be since the `Full-flowering date` column is a *float* instead of an integer.

# %%
df['day of month'] = df['Full-flowering date'].dropna().astype(int)
df.head()
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11  812                       92.0                401.0          1.0
# 14  815                      105.0                415.0          1.0
# 30  831                       96.0                406.0          1.0
# 50  851                      108.0                418.0          1.0
# 52  853                      104.0                414.0          1.0
#
#     Data type code          Reference Name  rolling_date  month  day of month
# 11             2.0              NIHON-KOKI           NaN  April           401
# 14             2.0              NIHON-KOKI           NaN  April           415
# 30             2.0              NIHON-KOKI           NaN  April           406
# 50             2.0  MONTOKUTENNO-JITSUROKU           NaN  April           418
# 52             2.0  MONTOKUTENNO-JITSUROKU         101.0  April           414

# %% [markdown]
# And if you try to convert it to an int, **pandas yells at you!**

# %% [markdown]
# That's because, as you can read, you can't have an `NaN` be an integer. But, for some reason, it *can* be a float. Ugh! So what we'll do is **drop all of the na values, then convert them to integers to get rid of the decimals.**
#
# I'll show you the first 5 here.

# %%
df['Full-flowering date'].dropna().astype(int).head()
# Out:
# 11    401
# 14    415
# 30    406
# 50    418
# 52    414
# Name: Full-flowering date, dtype: int64

# %% [markdown]
# On the next line, I take the first character of the row and add a bunch of exclamation points on it. I want you to edit this code to **return the last TWO digits of the number**. This only shows you the first 5, by the way.
#
# You might want to look up 'list slicing.'

# %%
df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[0] + "!!!").head()
# Out:
# 11    4!!!
# 14    4!!!
# 30    4!!!
# 50    4!!!
# 52    4!!!
# Name: Full-flowering date, dtype: object

# %% [markdown]
# Now that you've successfully extracted the last two letters, save them into a new column called `'day-of-month'`

# %%
df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: "" + value[1] + value[2]).head()
# Out:
# 11    01
# 14    15
# 30    06
# 50    18
# 52    14
# Name: Full-flowering date, dtype: object

# %%
# df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[1:]).head()

# %% [markdown]
# ### 20. Adding a date column
#
# Now take the `'month'` and `'day-of-month'` columns and combine them in order to create a new column called `'date'`

# %%
df['day'] = df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: "" + value[1] + value[2])

# %%
df['day'] = df['day'].astype(str)

# %%
df['month']=df['month'].astype(str)

# %%
df['Monthday']  = df['month']+'-'+df['day']

# %%
df['Monthday']
# Out:
# 11      April-01
# 14      April-15
# 30      April-06
# 50      April-18
# 52      April-14
# 63      April-09
# 65      April-16
# 68      April-05
# 88      April-14
# 90      April-19
# 91      April-17
# 93      April-16
# 94      April-14
# 95      April-13
# 101     April-12
# 107     April-07
# 111     April-04
# 112     April-20
# 116     April-05
# 122     April-14
# 125     April-08
# 129     April-07
# 132     April-16
# 140     April-19
# 148     April-17
# 149     April-05
# 154     March-30
# 156     April-22
# 157     April-19
# 158     April-07
#           ...
# 1185    April-12
# 1186    April-05
# 1187    April-15
# 1188    April-03
# 1189    March-29
# 1190    April-07
# 1191    April-03
# 1192    April-07
# 1193    April-09
# 1194    April-09
# 1195    April-12
# 1196    April-07
# 1197    April-01
# 1198    April-04
# 1199    April-09
# 1200    April-06
# 1201    April-01
# 1202    April-08
# 1203    April-01
# 1204    April-09
# 1205    April-08
# 1206    April-07
# 1207    April-04
# 1208    April-05
# 1209    April-05
# 1210    April-09
# 1211    April-10
# 1212    April-03
# 1213    April-04
# 1214    April-03
# Name: Monthday, Length: 827, dtype: object

# %% [markdown]
# # YOU ARE DONE.
#
# And **incredible.**
